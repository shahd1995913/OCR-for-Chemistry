# %%
string = 'CCCCO=C(CC)CC'
letter = 'CC(C)=O'
if letter in string :
  product =  string.replace("CC(C)=O", "CC(C)O")
elif "CC(CC)=O" in string: 
  product =  string.replace("CC(CC)=O", "CC(CC)O" ) 
elif  "CC(C(C)C)=O" in string :
  product =  string.replace("CC(C(C)C)=O", "CC(C(C)C)O" )
elif  "CC(C(C)(C)C)=O" in string :
   product =  string.replace("CC(C(C)(C)C)=O", "CC(C(C)(C)C)O" ) 
elif  "O=C(CC)CC" in string  :
    product =  string.replace("O=C(CC)CC", "OC(CC)CC" )
elif "O=C(CC)C(C)C" in string:
    product =  string.replace("O=C(CC)C(C)C", "OC(CC)C(C)C" )
elif  "O=C(CC)C(C)(C)C" in string :
    product =  string.replace("O=C(CC)C(C)(C)C", "OC(CC)C(C)(C)C" )
elif  "O=C(C(C)C)C(C)C" in string:
    product =  string.replace("O=C(C(C)C)C(C)C", "OC(C(C)C)C(C)C" )
elif "O=C(C(C)(C)C)C(C)C" in string :
  product =  string.replace("O=C(C(C)(C)C)C(C)C", "OC(C(C)(C)C)C(C)C" )
elif "O=C([C@@H](C)CC)/C(C)=C/C" in string :
  product =  string.replace("O=C([C@@H](C)CC)/C(C)=C/C", "O=C([C@@H](C)CC)/C(C)=C/C" )
elif "O=C([C@H](C)CC)/C(C)=C/C" in string :
  product =  string.replace("O=C([C@H](C)CC)/C(C)=C/C", "O=C([C@H](C)CC)/C(C)=C/C" )
elif "O=C1[C@@H]2C(CCC2)CCC1" in string :
  product =  string.replace("O=C1[C@@H]2C(CCC2)CCC1", "OC1[C@@H]2C(CCC2)CCC1" )
elif "O=C1CCCCCCCC(C)C1" in string :
  product =  string.replace("O=C1CCCCCCCC(C)C1", "OC1CCCCCCCC(C)C1" )
elif "O=C1C2=C(C=CC=N2)CCC1" in string :
  product =  string.replace("O=C1C2=C(C=CC=N2)CCC1", "OC1C2=C(C=CC=N2)CCC1" )
elif "O=C(CCC1)C2C1CC(CCCC3)=C3C2" in string :
  product =  string.replace("O=C(CCC1)C2C1CC(CCCC3)=C3C2", "OC(CCC1)C2C1CC(CCCC3)=C3C2" )
elif "O=C(C1CCCCC1)/C(C)=C(C)/C" in string :
  product =  string.replace("O=C(C1CCCCC1)/C(C)=C(C)/C", "OC(C1CCCCC1)/C(C)=C(C)/C" )
elif "O=C(C1CCCCC1)/C(C)=C/C" in string:
  product =  string.replace("O=C(C1CCCCC1)/C(C)=C/C", "OC(C1CCCCC1)/C(C)=C/C" )
elif "O=C(C1=CC=CC=C1)C(C)=C" in string:
  product =  string.replace("O=C(C1=CC=CC=C1)C(C)=C", "OC(C1=CC=CC=C1)C(C)=C" )
elif "O=C(C1=CC=CC=C1)C=C" in string:
  product =  string.replace("O=C(C1=CC=CC=C1)C=C", "OC(C1=CC=CC=C1)C=C")
elif "O=C(C1CCCC1)C=C" in string:
  product =  string.replace("O=C(C1CCCC1)C=C", "OC(C1CCCC1)C=C" )
elif "O=C(C(C)=C)C=C" in string:
  product =  string.replace("O=C(C(C)=C)C=C", "OC(C(C)=C)C=C" )
elif "O=C(C=C)C=C" in string:
  product =  string.replace("O=C(C=C)C=C", "OC(C=C)C=C" )
elif "O=C1C2=C(CCCC2)CC3C1CCCC3" in string :
  product =  string.replace("O=C1C2=C(CCCC2)CC3C1CCCC3", "OC1C2=C(CCCC2)CC3C1CCCC3" )
elif "O=C1C2=C(C=CC=C2)CC3=C1C=CC=C3" in string :
  product =  string.replace("O=C1C2=C(C=CC=C2)CC3=C1C=CC=C3", "OC1C2=C(C=CC=C2)CC3=C1C=CC=C3" )
elif "O=C1C2C(CCC2)CCC1" in string :
  product =  string.replace("O=C1C2C(CCC2)CCC1", "OC1C2C(CCC2)CCC1" )
elif "O=C1C(C(C)(C)C)CCCC1" in string :
  product =  string.replace("O=C1C(C(C)(C)C)CCCC1", "OC1C(C(C)(C)C)CCCC1" )
elif "O=C1C(C(C)C)CCCC1" in string :
  product =  string.replace("O=C1C(C(C)C)CCCC1", "OC1C(C(C)C)CCCC1" )
elif "O=C1C(CC)CCCC1" in string :
  product =  string.replace("O=C1C(CC)CCCC1", "OC1C(CC)CCCC1" )
elif "O=C1C(CC)CCCC1" in string :
  product =  string.replace("O=C1C(CC)CCCC1", "OC1C(CC)CCCC1" )
elif "O=C1CCCCC1" in string :
  product =  string.replace("O=C1CCCCC1", "OC1CCCCC1" )
elif "O=C1C2=C(C=CC=C2)CC1" in string :
  product =  string.replace("O=C1C2=C(C=CC=C2)CC1", "OC1C2=C(C=CC=C2)CC1" )
elif "O=C1C(CC)CCCC1" in string :
  product =  string.replace("O=C1C(CC)CCCC1", "OC1C(CC)CCCC1" )
elif "O=C1C(CC)CCCC1" in string :
  product =  string.replace("O=C1C(CC)CCCC1", "OC1C(CC)CCCC1" )
elif "O=C1CCCCC1" in string :
  product =  string.replace("O=C1CCCCC1", "OC1CCCCC1" )
elif "O=C1C2=C(C=CC=C2)CC1" in string :
  product =  string.replace("O=C1C2=C(C=CC=C2)CC1", "OC1C2=C(C=CC=C2)CC1" )
elif "O=C1C2C(CCCC2)CC1" in string :
  product =  string.replace("O=C1C2C(CCCC2)CC1", "OC1C2C(CCCC2)CC1" )
elif "O=C1C(C(C)(C)C)CCC1" in string :
  product =  string.replace("O=C1C(C(C)(C)C)CCC1", "OC1C(C(C)(C)C)CCC1" )
elif "O=C1C(C(C)C)CCC1" in string :
  product =  string.replace("O=C1C(C(C)C)CCC1", "OC1C(C(C)C)CCC1" )
elif "O=C1C(C=C)CCC1" in string :
  product =  string.replace("O=C1C(C=C)CCC1", "OC1C(C=C)CCC1" )
elif "O=C1C(CC)CCC1" in string :
  product =  string.replace("O=C1C(CC)CCC1", "OC1C(CC)CCC1" )
elif "O=C1(C)CCC1" in string :
  product =  string.replace("O=C1(C)CCC1", "OC1(C)CCC1" )
elif "O=C1CCCC1" in string :
  product =  string.replace("O=C1CCCC1", "OC1CCCC1" )
elif "O=C(C1CCCCC1)C2=CC=CC=C2" in string :
  product =  string.replace("O=C(C1CCCCC1)C2=CC=CC=C2", "OC(C1CCCCC1)C2=CC=CC=C2" )
elif "O=C(C=C)C1=CC=CC=C1" in string :
  product =  string.replace("O=C(C=C)C1=CC=CC=C1", "OC(C=C)C1=CC=CC=C1" )
elif "O=C(C(C)(C)C)C1=CC=CC=C1" in string :
  product =  string.replace("O=C(C(C)(C)C)C1=CC=CC=C1", "OC(C(C)(C)C)C1=CC=CC=C1" )
elif "O=C(C(C)C)C1=CC=CC=C1" in string :
  product =  string.replace("O=C(C(C)C)C1=CC=CC=C1", "OC(C(C)C)C1=CC=CC=C1" )
elif "O=C(CC)C1=CC=CC=C1" in string :
  product =  string.replace("O=C(CC)C1=CC=CC=C1", "OC(CC)C1=CC=CC=C1" )
elif "O=C(C(C)C)C1=CC=CC=C1" in string :
  product =  string.replace("O=C(C(C)C)C1=CC=CC=C1", "OC(C(C)C)C1=CC=CC=C1" )
elif "O=C(CC)C1=CC=CC=C1" in string :
  product =  string.replace("O=C(CC)C1=CC=CC=C1", "OC(CC)C1=CC=CC=C1" )
elif "CC(C1=CC=CC=C1)=O" in string :
  product =  string.replace("CC(C1=CC=CC=C1)=O", "CC(C1=CC=CC=C1)O" )
elif "O=C(C(C)(C)C)/C(C)=C(C)/C" in string :
  product =  string.replace("O=C(C(C)(C)C)/C(C)=C(C)/C", "OC(C(C)(C)C)/C(C)=C(C)/C" )
elif "O=C(C(C)C)/C(C)=C(C)/C" in string :
  product =  string.replace("O=C(C(C)C)/C(C)=C(C)/C", "OC(C(C)C)/C(C)=C(C)/C" )
elif "O=C(CC)/C(C)=C(C)/C" in string :
  product =  string.replace("O=C(CC)/C(C)=C(C)/C", "OC(CC)/C(C)=C(C)/C" )
elif "CC(/C(C)=C(C)/C)=O" in string :
  product =  string.replace("CC(/C(C)=C(C)/C)=O", "CC(/C(C)=C(C)/C)O" )
elif "O=C(C(C)(C)C)/C(C)=C/C" in string :
  product =  string.replace("O=C(C(C)(C)C)/C(C)=C/C", "OC(C(C)(C)C)/C(C)=C/C" )
elif "O=C(C(C)C)/C(C)=C/C" in string :
  product =  string.replace("O=C(C(C)C)/C(C)=C/C", "OC(C(C)C)/C(C)=C/C" )
elif "O=C(CC)/C(C)=C/C" in string :
  product =  string.replace("O=C(CC)/C(C)=C/C", "OC(CC)/C(C)=C/C" )
elif "CC(/C(C)=C/C)=O" in string :
  product =  string.replace("CC(/C(C)=C/C)=O", "CC(/C(C)=C/C)O" )
elif "O=C(C(C)(C)C)C(C)=C" in string :
  product =  string.replace("O=C(C(C)(C)C)C(C)=C", "OC(C(C)(C)C)C(C)=C" )
elif "O=C(C(C)C)C(C)=C" in string :
  product =  string.replace("O=C(C(C)C)C(C)=C", "OC(C(C)C)C(C)=C" )
elif "O=C(CC)C(C)=C" in string :
  product =  string.replace("O=C(CC)C(C)=C", "OC(CC)C(C)=C" )
elif "CC(C(C)=C)=O" in string :
  product =  string.replace("CC(C(C)=C)=O", "CC(C(C)=C)O" )
elif "O=C(C(C)(C)C)C=C" in string :
  product =  string.replace("O=C(C(C)(C)C)C=C", "OC(C(C)(C)C)C=C" )
elif "O=C(C(C)C)C=C" in string :
  product =  string.replace("O=C(C(C)C)C=C", "OC(C(C)C)C=C" )
elif "O=C(CC)C=C" in string :
  product =  string.replace("O=C(CC)C=C", "OC(CC)C=C" )
elif "CC(C=C)=O" in string :
  product =  string.replace("CC(C=C)=O", "CC(C=C)O" )
elif "O=C(C(C)(C)C)C(C)C" in string :
  product =  string.replace("O=C(C(C)(C)C)C(C)C", "OC(C(C)(C)C)C(C)C" )
print("Ketone Reactant before replacement:   "+string)
print("Ketone Product Aftar :")
print(product)

string = 'CCCCOO=CC(C)C'
if "O=CCC" in string :
  product =  string.replace("O=CCC", "OCCC" )
elif "O=CC(C)C" in string :
  product =  string.replace("O=CC(C)C", "OCC(C)C" )
elif "O=CC=C" in string :
  product =  string.replace("O=CC=C", "OCC=C" )
elif "O=CC(C)(C)C" in string :
  product =  string.replace("O=CC(C)(C)C", "OCC(C)(C)C" )
elif "O=CC1=CC=CC=C1" in string :
  product =  string.replace("O=CC1=CC=CC=C1", "OCC1=CC=CC=C1" )
elif "O=CC1=CC=CC=C1C" in string :
  product =  string.replace("O=CC1=CC=CC=C1C", "OCC1=CC=CC=C1C" )
elif "O=CC1=CC=CC=C1CC" in string :
  product =  string.replace("O=CC1=CC=CC=C1CC", "OCC1=CC=CC=C1CC" )
elif "O=CC1=CC=CC=C1C(C)C" in string :
  product =  string.replace("O=CC1=CC=CC=C1C(C)C", "OCC1=CC=CC=C1C(C)C" )
elif "O=CC1=CC=CC=C1C(C)(C)C" in string :
  product =  string.replace("O=CC1=CC=CC=C1C(C)(C)C", "OCC1=CC=CC=C1C(C)(C)C" )
elif "CC1C(C=O)CC2C(CCCC2)C1" in string :
  product =  string.replace("CC1C(C=O)CC2C(CCCC2)C1", "CC1C(CO)CC2C(CCCC2)C1" )
elif "O=CC1CCCC1" in string :
  product =  string.replace("O=CC1CCCC1", "OCC1CCCC1" )
elif "O=CC1CCCC1C" in string :
  product =  string.replace("O=CC1CCCC1C", "OCC1CCCC1C" )
elif "O=CC1=CC(CCCC2)=C2C=C1C(C)(C)C" in string :
  product =  string.replace("O=CC1=CC(CCCC2)=C2C=C1C(C)(C)C", "OCC1=CC(CCCC2)=C2C=C1C(C)(C)C" )
elif "O=CC1CCCC1CC" in string :
  product =  string.replace("O=CC1CCCC1CC", "OCC1CCCC1CC" )
elif "O=CC1CCCC1C(C)C" in string :
  product =  string.replace("O=CC1CCCC1C(C)C", "OCC1CCCC1C(C)C" )
elif "O=CC1CCCC1C(C)(C)C" in string :
  product =  string.replace("O=CC1CCCC1C(C)(C)C", "OCC1CCCC1C(C)(C)C" )
elif "CC1C(C=O)CC2C(CC(CCCC3)C3C2)C1" in string :
  product =  string.replace("CC1C(C=O)CC2C(CC(CCCC3)C3C2)C1", "CC1C(CO)CC2C(CC(CCCC3)C3C2)C1" )
elif "O=C[C@H]1CCCC1C(C)C" in string :
  product =  string.replace("O=C[C@H]1CCCC1C(C)C", "OC[C@H]1CCCC1C(C)C" )
elif "O=C[C@@H]1CCCC1C(C)C" in string :
  product =  string.replace("O=C[C@@H]1CCCC1C(C)C", "OC[C@@H]1CCCC1C(C)C" )
print("Aldehyde Reactant before replacement:   "+string)
print("Aldehyde Product Aftar :")
print(product)
# Out:
# Ketone Reactant before replacement:   CCCCO=C(CC)CC
# Ketone Product Aftar :
# CCCCOC(CC)CC
# Aldehyde Reactant before replacement:   CCCCOO=CC(C)C
# Aldehyde Product Aftar :
# CCCCOOCC(C)C
